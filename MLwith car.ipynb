# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("C:\\Users\\visha\\OneDrive\\Desktop\\2017_Yellow_Taxi_Trip_Data.csv")

# %%
dataset.head(3)
# Out:
#    Unnamed: 0  VendorID   tpep_pickup_datetime  tpep_dropoff_datetime  \
# 0    24870114         2  03/25/2017 8:55:43 AM  03/25/2017 9:09:47 AM
# 1    35634249         1  04/11/2017 2:53:28 PM  04/11/2017 3:19:58 PM
# 2   106203690         1  12/15/2017 7:26:56 AM  12/15/2017 7:34:08 AM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           100           231             1         13.0    0.0      0.5
# 1           186            43             1         16.0    0.0      0.5
# 2           262           236             1          6.5    0.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount
# ...

# %%
dataset.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0               0
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
sns.displot(dataset["fare_amount"])
# Out:
# C:\Users\visha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
dataset.shape
# Out:
# (22699, 18)

# %%
np.sort(dataset["trip_distance"])
# Out:
# array([ 0.  ,  0.  ,  0.  , ..., 32.72, 33.92, 33.96])

# %%
dataset.head()
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %%
dataset["trip_distance"].min()
# Out:
# 0.0

# %%
dataset.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
dataset["total_amount"].min()
# Out:
# -120.3

# %%
dataset["total_amount"].max()
# Out:
# 1200.29

# %%
dataset.shape
# Out:
# (22699, 18)

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'VendorID', 'tpep_pickup_datetime',
#        'tpep_dropoff_datetime', 'passenger_count', 'trip_distance',
#        'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %%
X = dataset.drop(["tpep_dropoff_datetime" ,"store_and_fwd_flag",
                 "tpep_pickup_datetime", "total_amount"] , axis = 1)

# %%
X
# Out:
#        Unnamed: 0  VendorID  passenger_count  trip_distance  RatecodeID  \
# 0        24870114         2                6           3.34           1
# 1        35634249         1                1           1.80           1
# 2       106203690         1                1           1.00           1
# 3        38942136         2                1           3.70           1
# 4        30841670         2                1           4.37           1
# ...           ...       ...              ...            ...         ...
# 22694    14873857         2                3           0.61           1
# 22695    66632549         2                1          16.71           2
# 22696    74239933         2                1           0.42           1
# 22697    60217333         2                1           2.36           1
# 22698    17208911         1                1           2.10           1
#
#        PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %%
y = dataset["total_amount"]

# %%
y
# Out:
# 0        16.56
# 1        20.80
# 2         8.75
# 3        27.69
# 4        17.80
#          ...
# 22694     5.80
# 22695    73.20
# 22696     5.30
# 22697    13.00
# 22698    14.15
# Name: total_amount, Length: 22699, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.3)

# %%
print("shape of X_train =",X_train.shape)
print("shape of X_test =",X_test.shape)
print("shape of y_train =",y_train.shape)
print("shape of y_test =",y_test.shape)
# Out:
# shape of X_train = (15889, 14)
# shape of X_test = (6810, 14)
# shape of y_train = (15889,)
# shape of y_test = (6810,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-3.80816358e-11,  8.96822848e-03,  3.51865306e-04,  4.79869528e-04,
#        -6.07662671e-04, -2.55481281e-05, -2.03583308e-05, -8.78981497e-03,
#         1.00016219e+00,  9.92990974e-01,  1.01616523e+00,  9.99274982e-01,
#         9.99509481e-01,  9.65756919e-01])

# %%
lr.intercept_
# Out:
# 0.015223798012709011

# %%
x_train = lr.predict(X_train)
x_train
# Out:
# array([ 7.30441215, 11.77372606, 19.12735944, ..., 10.79782654,
#        14.17058284,  9.36990744])
